# %%
# %pylab inline
import glob
import pandas as pd
import math
import dateutil
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
path = '../csv/original/'
filenames = glob.glob(path + "/*.csv")

list_ = []
frame = pd.DataFrame()

# Para cada um dos csv
for filename in filenames:
    # Leia o CSV
    df = pd.read_csv(filename, index_col = False)
    # Coloque na lista de CSV
    list_.append(df)

frame = pd.concat(list_)

# Remover a ultima linha do frame (NaN line)
frame = frame.drop(frame.index[len(frame)-1])

# Dataframe
df_clean = frame.dropna()

df_clean.head()
# Out:
#   Data Emissão     OB Origem     NE Origem           No Processo  \
# 0   01/09/2017  2017OB805678  2016NE000034  23106.098701/2017-44
# 1   01/09/2017  2017OB805680  2014NE000150  23106.013536/2014-16
# 2   01/09/2017  2017OB805681  2015NE000101  23106.016174/2014-15
# 3   01/09/2017  2017OB805682  2015NE000101  23106.016174/2014-15
# 4   01/09/2017  2017OB805683  2017NE000069  23106.106542/2017-69
#
#            Credor                      Nome Credor  \
# 0  032.022.191-11      MARIANA FIGUEIREDO\nMIRANDA
# 1  991.772.341-20  MARIANA COSTA BERNARDES\nMATIAS
# 2  694.622.751-49       PEDRO PAULO MURCE\nMENESES
# 3  602.122.331-49      ANDRE LUIZ MARQUES\nSERRANO
# 4  020.971.891-99            MARCO ANTONIO ALMEIDA
#
#                                           Finalidade Fonte de Recurso  \
# 0  PAGAMENTO DE FOLHA 8/2017-746, REFERENTE A AUX...        100000000
# 1  PAGAMENTO DE FOLHA 8/2017-776, REFERENTE A PRE...       6151000000
# 2  PAGAMENTO DA FOLHA 08/2017-773 // PRESTACAO DE...        100049101
# 3  PAGAMENTO DA FOLHA 08/2017-774 // PRESTACAO DE...        100049101
# 4  PAGAMENTO DE FOLHA 8/2017-770, REFERENTE A AUX...       6151000000
#
#   Natureza Detalhada           Nome Natureza Detalhada UG Executora  \
# 0         3390.20.01           AUXILIO A PESQUISADORES       154019
# 1         3390.36.06  SERVICOS TECNICOS\nPROFISSIONAIS       154019
# 2         3390.36.06  SERVICOS TECNICOS\nPROFISSIONAIS       154019
# 3         3390.36.06  SERVICOS TECNICOS\nPROFISSIONAIS       154019
# 4         3390.20.01           AUXILIO A PESQUISADORES       154019
#
#                                   Nome UG Executora Mês Emissão      Pago
# 0  CENTRO DE APOIO AO\nDESENVOLV. TECNOLOGICO-\nCDT           9  3.250,00
# 1  CENTRO DE APOIO AO\nDESENVOLV. TECNOLOGICO-\nCDT           9  6.227,52
# 2  CENTRO DE APOIO AO\nDESENVOLV. TECNOLOGICO-\nCDT           9  2.003,34
# 3  CENTRO DE APOIO AO\nDESENVOLV. TECNOLOGICO-\nCDT           9  6.155,74
# 4  CENTRO DE APOIO AO\nDESENVOLV. TECNOLOGICO-\nCDT           9  1.800,00

# %%
def still_numbers_and_commas(element):
    return "".join(i for i in element if i.isdigit() or i == ',')

df_clean['Pago'] = df_clean['Pago'].astype(str)

df_clean['Pago'] = df_clean['Pago'].apply(still_numbers_and_commas)

df_clean['Pago'] = df_clean['Pago'].str.replace(',','.')

df_clean['Pago'].head()
# Out:
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0    3250.00
# 1    6227.52
# 2    2003.34
# 3    6155.74
# 4    1800.00
# Name: Pago, dtype: object

# %%
df_clean['Pago'].fillna(0, inplace=True)
# Out:
# /home/freemanpivo/.local/lib/python3.7/site-packages/pandas/core/generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_clean['Nome Credor'] = df_clean['Nome Credor'].str.replace('\n',' ')
df_clean['Nome Credor'] = df_clean['Nome Credor'].str.replace('\r',' ')

df_clean['Nome UG Executora'] = df_clean['Nome UG Executora'].str.replace('\n',' ')
df_clean['Nome UG Executora'] = df_clean['Nome UG Executora'].str.replace('\r',' ')

df_clean['Nome Natureza Detalhada'] = df_clean['Nome Natureza Detalhada'].str.replace('\n',' ')
df_clean['Nome Natureza Detalhada'] = df_clean['Nome Natureza Detalhada'].str.replace('\r',' ')
df_clean['Nome Natureza Detalhada'] = df_clean['Nome Natureza Detalhada'].str.replace('.',' ')
df_clean['Nome Natureza Detalhada'] = df_clean['Nome Natureza Detalhada'].str.replace('-',' ')
df_clean['Nome Natureza Detalhada'] = df_clean['Nome Natureza Detalhada'].str.replace(',',' ')
df_clean['Nome Natureza Detalhada'] = df_clean['Nome Natureza Detalhada'].str.replace('/',' ')
df_clean['Nome Natureza Detalhada'] = df_clean['Nome Natureza Detalhada'].str.replace('  ',' ')
df_clean['Nome Natureza Detalhada'] = df_clean['Nome Natureza Detalhada'].str.replace('   ',' ')
df_clean['Nome Natureza Detalhada'] = df_clean['Nome Natureza Detalhada'].str.replace('    ',' ')
df_clean['Nome Natureza Detalhada'] = df_clean['Nome Natureza Detalhada'].str.replace('T I','TI')

df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('\n',' ')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('//','')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('\r',' ')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('0','')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('1','')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('2','')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('3','')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('4','')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('5','')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('6','')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('7','')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('8','')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('9','')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace('/-','')
df_clean['Finalidade'] = df_clean['Finalidade'].str.replace(',','')
# Out:
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_clean.head()
# Out:
#   Data Emissão     OB Origem     NE Origem           No Processo  \
# 0   01/09/2017  2017OB805678  2016NE000034  23106.098701/2017-44
# 1   01/09/2017  2017OB805680  2014NE000150  23106.013536/2014-16
# 2   01/09/2017  2017OB805681  2015NE000101  23106.016174/2014-15
# 3   01/09/2017  2017OB805682  2015NE000101  23106.016174/2014-15
# 4   01/09/2017  2017OB805683  2017NE000069  23106.106542/2017-69
#
#            Credor                     Nome Credor  \
# 0  032.022.191-11      MARIANA FIGUEIREDO MIRANDA
# 1  991.772.341-20  MARIANA COSTA BERNARDES MATIAS
# 2  694.622.751-49       PEDRO PAULO MURCE MENESES
# 3  602.122.331-49      ANDRE LUIZ MARQUES SERRANO
# 4  020.971.891-99           MARCO ANTONIO ALMEIDA
#
#                                           Finalidade Fonte de Recurso  \
# 0  PAGAMENTO DE FOLHA  REFERENTE A AUXILIO PESQUI...        100000000
# 1  PAGAMENTO DE FOLHA  REFERENTE A PRESTACAO DE S...       6151000000
# 2  PAGAMENTO DA FOLHA   PRESTACAO DE SERVICO  PRO...        100049101
# 3  PAGAMENTO DA FOLHA   PRESTACAO DE SERVICO  PRO...        100049101
# 4  PAGAMENTO DE FOLHA  REFERENTE A AUXILIO PESQUI...       6151000000
#
#   Natureza Detalhada          Nome Natureza Detalhada UG Executora  \
# 0         3390.20.01          AUXILIO A PESQUISADORES       154019
# 1         3390.36.06  SERVICOS TECNICOS PROFISSIONAIS       154019
# 2         3390.36.06  SERVICOS TECNICOS PROFISSIONAIS       154019
# 3         3390.36.06  SERVICOS TECNICOS PROFISSIONAIS       154019
# 4         3390.20.01          AUXILIO A PESQUISADORES       154019
#
#                                 Nome UG Executora Mês Emissão     Pago
# 0  CENTRO DE APOIO AO DESENVOLV. TECNOLOGICO- CDT           9  3250.00
# 1  CENTRO DE APOIO AO DESENVOLV. TECNOLOGICO- CDT           9  6227.52
# 2  CENTRO DE APOIO AO DESENVOLV. TECNOLOGICO- CDT           9  2003.34
# 3  CENTRO DE APOIO AO DESENVOLV. TECNOLOGICO- CDT           9  6155.74
# 4  CENTRO DE APOIO AO DESENVOLV. TECNOLOGICO- CDT           9  1800.00

# %%
# Check the unique values

df_clean['Pago'] = df_clean['Pago'].astype(float)
df_ = df_clean

df_ = df_[df_["Pago"] < 50]
count = df_['Pago'].value_counts()
count
# unique_values_pago = df_clean['Pago'].value_counts()
# valores_ocorrencias = unique_values_pago.sort_values()
# valores_ocorrencias
# Out:
# /home/freemanpivo/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 7.75     41
# 23.81    41
# 30.24    38
# 17.80    14
# 26.01    13
# 39.23    12
# 5.82     12
# 29.98    12
# 7.31     12
# 49.96    10
# 6.65      9
# 7.00      9
# 0.03      7
# 36.72     7
# 47.53     7
# 36.00     7
# 12.00     7
# 17.45     7
# 49.36     7
# 20.84     7
# 7.21      6
# 0.08      6
# 14.00     6
# 34.52     6
# 0.01      6
# 0.10      6
# 0.58      5
# 19.60     5
# 0.30      5
# 49.51     5
#          ..
# 17.11     1
# 3.61      1
# 1.84      1
# 45.99     1
# 0.94      1
# 46.04     1
# 26.33     1
# 13.06     1
# 13.97     1
# 2.12      1
# 3.56      1
# 17.26     1
# 11.57     1
# 19.20     1
# 42.17     1
# 2.86      1
# 18.97     1
# 17.71     1
# 15.76     1
# 33.02     1
# 6.49      1
# 8.85      1
# 30.10     1
# 1.64      1
# 16.12     1
# 33.28     1
# 38.64     1
# 12.22     1
# 33.44     1
# 5.66      1
# Name: Pago, Length: 847, dtype: int64

# %%
unique_values_pago = df_clean.groupby('Nome Credor')['Pago'].nunique()
unique_values_pago.sort_values().tail()
# Out:
# Nome Credor
# ITAU UNIBANCO S.A.                                       132
# BANCO COOPERATIVO DO BRASIL S/A                          133
# CAIXA ECONOMICA FEDERAL                                  259
# COMPANHIA DE SANEAMENT AMBIENTAL DO DISTRITO FEDERAL     264
# BANCO DO BRASIL SA                                      1303
# Name: Pago, dtype: int64
