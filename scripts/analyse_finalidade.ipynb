# %%
# %pylab inline
from wordcloud import WordCloud, STOPWORDS
import pandas as pd
import math
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('../csv/parsed/2017_v1.0.csv')

# %%
df.head()
# Out:
#   Data Emissão     OB Origem           No Processo          Credor  \
# 0   01/09/2017  2017OB805678  23106.098701/2017-44  032.022.191-11
# 1   01/09/2017  2017OB805680  23106.013536/2014-16  991.772.341-20
# 2   01/09/2017  2017OB805681  23106.016174/2014-15  694.622.751-49
# 3   01/09/2017  2017OB805682  23106.016174/2014-15  602.122.331-49
# 4   01/09/2017  2017OB805683  23106.106542/2017-69  020.971.891-99
#
#                       Nome Credor  \
# 0      MARIANA FIGUEIREDO MIRANDA
# 1  MARIANA COSTA BERNARDES MATIAS
# 2       PEDRO PAULO MURCE MENESES
# 3      ANDRE LUIZ MARQUES SERRANO
# 4           MARCO ANTONIO ALMEIDA
#
#                                           Finalidade Fonte de Recurso  \
# 0  PAGAMENTO DE FOLHA 8/2017-746, REFERENTE A AUX...        100000000
# 1  PAGAMENTO DE FOLHA 8/2017-776, REFERENTE A PRE...       6151000000
# 2  PAGAMENTO DA FOLHA 08/2017-773  PRESTACAO DE S...        100049101
# ...

# %%
corpus = df['Finalidade'].astype('str')
corpus = ' '.join(corpus.values)

stopwords = set(STOPWORDS)
stopwords.update(["CONF","MEMO","DAC","DAE","SEI","DE", "PROCESSO", "DA", "AO MES", "AO", "MES"])

img = WordCloud(
    background_color='white',
    height=2000,
    width=4000,
    stopwords = stopwords 
).generate(corpus)

plt.figure(figsize=(16,8))
plt.axis('off')
plt.imshow(img, interpolation='bilinear')
